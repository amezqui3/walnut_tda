# %%
import pandas as pd
import numpy as np

# %%
src = '../hpcc/traditional/'
filename = '../all_phenos_for_Erik_221024.csv'
attr = pd.read_csv(filename)
print(attr.shape)
# Out:
# (720, 20)

# %%
col_names = ['bname', 'wname',
             'nut_length','nut_height', 'nut_width',
             'nut_vol',
             'nut_va3d',
             'nut_ratio_feret',
             'nut_area',
             'nut_sphericity',
             'nut_cnvx_area',
             'nut_cnvx_vol',
             'nut_ratio_cnvx_area',
             'nut_inv_ratio_cnvx_vol',
             'krumbein',
             'sneed',
             'air_vol', 'meat_vol', 'shell_vol', 'vein_vol',
             'air_ratio_vol', 'meat_ratio_vol', 'shell_ratio_vol', 'vein_ratio_vol',
             'shell_rugosity',
             'shell_thickness',
             'shell_ext_ratio', 'shell_prot_ratio',
             'shell_ext_vol', 'shell_prot_vol',
             'meat_length', 'meat_height', 'meat_width',
             'meat_area',
             'meat_cnvx_vol',
             'meat_cnvx_area',
             'meat_ratio_cnvx_area',
             'meat_inv_ratio_cnvx_vol',
             'meat_cavity_area',
             'meat_cavity_vol',
             'meat_arc_height',
             'meat_cavity_height',
             'meat_sphericity',
             'meat_ratio_cavity_area',
             'meat_ratio_cavity_vol',
             'rho_mvs', 'rho_vvs', 'rho_vvm'
             ]

filename = src + 'traditional_raw.csv'
raw = pd.read_csv(filename, header=None, dtype={1:str}, names=col_names)
raw.loc[raw['bname'] == '201SBa_R5_T55', 'bname'] = '2014SBa_R5_T55'
foo = raw.iloc[:, 30:33].values
MM = np.max(foo, axis=1)
mm = np.min(foo, axis=1)
raw['meat_ratio_feret'] = MM/mm

raw['nut_vol_sa'] = raw['meat_vol'] + raw['vein_vol'] + raw['shell_vol']

raw['meat_ratio_vol_sa'] = raw['meat_vol']/raw['nut_vol_sa']
raw['vein_ratio_vol_sa'] = raw['vein_vol']/raw['nut_vol_sa']
raw['shell_ratio_vol_sa'] = raw['shell_vol']/raw['nut_vol_sa']

raw['meat_ratio_cnvx_area'] = 1/raw['meat_ratio_cnvx_area']
raw['meat_inv_ratio_cnvx_vol'] = 1/raw['meat_inv_ratio_cnvx_vol']
raw = raw.drop(columns=['shell_ext_ratio', 'shell_ext_vol'])

#data = data.drop(columns = [''])
print(raw.shape)
raw.head()
# Out:
# (1301, 51)
#            bname wname  nut_length  nut_height  nut_width       nut_vol  \
# 0  2008SB_R4_T13   001   41.750477   33.582913  31.395051  20387.149371
# 1  2008SB_R4_T13   002   39.720443   33.450554  31.454860  20512.900734
# 2  2008SB_R4_T13   003   42.790987   35.768852  33.257804  24394.576769
# 3  2008SB_R4_T13   004   39.589858   34.400643  31.931823  21020.676969
# 4  2008SB_R4_T13   005   38.284326   34.049830  31.365337  19995.849647
#
#    nut_va3d  nut_ratio_feret     nut_area  nut_sphericity  ...  \
# 0  4.941865         1.329843  6147.314265        0.587088  ...
# 1  4.643222         1.262776  6045.635968        0.599414  ...
# 2  4.596968         1.286645  6763.478980        0.601418  ...
# 3  4.496373         1.239825  6079.521052        0.605870  ...
# 4  4.335537         1.220594  5809.316020        0.613271  ...
#
#    meat_ratio_cavity_area  meat_ratio_cavity_vol   rho_mvs   rho_vvs  \
# 0                0.034601               0.031335  0.840804  0.592775
# 1                0.033174               0.029986  0.846395  0.587884
# 2                0.040115               0.037996  0.837089  0.598603
# 3                0.031933               0.029688  0.840064  0.602599
# 4                0.032905               0.032489  0.825360  0.586143
#
#     rho_vvm  meat_ratio_feret    nut_vol_sa  meat_ratio_vol_sa  \
# 0  0.705009          1.526275  12880.783084           0.463951
# 1  0.694574          1.425155  13706.563584           0.469242
# 2  0.715100          1.486324  15546.904008           0.465462
# 3  0.717325          1.411052  14347.815998           0.482360
# 4  0.710167          1.314016  12806.076196           0.475517
#
#    vein_ratio_vol_sa  shell_ratio_vol_sa
# 0           0.195673            0.340377
# 1           0.207626            0.323132
# 2           0.203646            0.330892
# 3           0.211936            0.305704
# 4           0.186909            0.337574
#
# [5 rows x 51 columns]

# %%
cattraits = np.zeros((len(raw), 15)) - 1
UCACCSD = []

for i in range(len(cattraits)):
    locate, Rrow, Ttree = raw.iloc[i,0].split('_')
    row = int(Rrow[1:])
    tree = int(Ttree[1:])

    if locate == 'NewStuke':
        locate = 'New Stuke'
    elif locate in ['SelectD', 'SelectF', 'SelectC']:
        locate = 'Select Davis'

    metadf = attr[(attr['LOCATE']==locate) & (attr['ROW']==row) & (attr['TREE']==tree)]
    if len(metadf) > 0:
        ucaccsd = metadf['UCACCSD'].iloc[0]
    else:
        ucaccsd = ''
        print(raw.iloc[i,0])
    
    UCACCSD.append(ucaccsd)
# Out:
# 2014SBa_R5_T90
# 2014SBa_R5_T90
# 2014SBa_R5_T90
# 2014SBa_R5_T90
# 2014SBa_R5_T90
# SelectD_R9_T1
# SelectD_R9_T1
# SelectD_R9_T1
# SelectD_R9_T1
# SelectD_R9_T1
# SelectD_R9_T1
# SelectF_R25_T25
# SelectF_R25_T25
# SelectF_R25_T25
# SelectF_R25_T25
# SelectF_R25_T25
# SelectF_R25_T25
# SelectF_R25_T25
# SelectF_R25_T25
# SelectF_R32_T13
# SelectF_R32_T13
# SelectF_R32_T13
# SelectF_R32_T13
# SelectF_R32_T13
# SelectF_R32_T13
# SelectF_R32_T13
# SelectF_R32_T13

# %%
raw['UCACCSD'] = UCACCSD
foo = np.asarray([51] + list(range(51)))
raw = raw.iloc[:, foo]
raw.head()
# Out:
#      UCACCSD          bname wname  nut_length  nut_height  nut_width  \
# 0  06-005-27  2008SB_R4_T13   001   41.750477   33.582913  31.395051
# 1  06-005-27  2008SB_R4_T13   002   39.720443   33.450554  31.454860
# 2  06-005-27  2008SB_R4_T13   003   42.790987   35.768852  33.257804
# 3  06-005-27  2008SB_R4_T13   004   39.589858   34.400643  31.931823
# 4  06-005-27  2008SB_R4_T13   005   38.284326   34.049830  31.365337
#
#         nut_vol  nut_va3d  nut_ratio_feret     nut_area  ...  \
# 0  20387.149371  4.941865         1.329843  6147.314265  ...
# 1  20512.900734  4.643222         1.262776  6045.635968  ...
# 2  24394.576769  4.596968         1.286645  6763.478980  ...
# 3  21020.676969  4.496373         1.239825  6079.521052  ...
# 4  19995.849647  4.335537         1.220594  5809.316020  ...
#
#    meat_ratio_cavity_area  meat_ratio_cavity_vol   rho_mvs   rho_vvs  \
# 0                0.034601               0.031335  0.840804  0.592775
# 1                0.033174               0.029986  0.846395  0.587884
# 2                0.040115               0.037996  0.837089  0.598603
# 3                0.031933               0.029688  0.840064  0.602599
# 4                0.032905               0.032489  0.825360  0.586143
#
#     rho_vvm  meat_ratio_feret    nut_vol_sa  meat_ratio_vol_sa  \
# 0  0.705009          1.526275  12880.783084           0.463951
# 1  0.694574          1.425155  13706.563584           0.469242
# 2  0.715100          1.486324  15546.904008           0.465462
# 3  0.717325          1.411052  14347.815998           0.482360
# 4  0.710167          1.314016  12806.076196           0.475517
#
#    vein_ratio_vol_sa  shell_ratio_vol_sa
# 0           0.195673            0.340377
# 1           0.207626            0.323132
# 2           0.203646            0.330892
# 3           0.211936            0.305704
# 4           0.186909            0.337574
#
# [5 rows x 52 columns]

# %%
kratio = raw.loc[:,'meat_ratio_vol'].values
q25,q50,q75 = np.quantile(kratio, [0.25,.5,0.75])
print(q25,q50,q75, sep='\t')
iqr = q75 - q25
floor = q25-2*iqr
print(floor)
nonemptyk = np.where(kratio > floor)[0]

data = raw.iloc[nonemptyk, :]
print(data.shape)

filename = src + 'traditional_phenotype_summary.csv'
print(filename)
data.to_csv(filename, index=False)

data.head()
# Out:
# 0.3074069767799232	0.3428273800154041	0.3714665882052332
# 0.17928775392930313
# (1264, 52)
# ../hpcc/traditional/traditional_phenotype_summary.csv
#      UCACCSD          bname wname  nut_length  nut_height  nut_width  \
# 0  06-005-27  2008SB_R4_T13   001   41.750477   33.582913  31.395051
# 1  06-005-27  2008SB_R4_T13   002   39.720443   33.450554  31.454860
# 2  06-005-27  2008SB_R4_T13   003   42.790987   35.768852  33.257804
# 3  06-005-27  2008SB_R4_T13   004   39.589858   34.400643  31.931823
# 4  06-005-27  2008SB_R4_T13   005   38.284326   34.049830  31.365337
#
#         nut_vol  nut_va3d  nut_ratio_feret     nut_area  ...  \
# 0  20387.149371  4.941865         1.329843  6147.314265  ...
# 1  20512.900734  4.643222         1.262776  6045.635968  ...
# 2  24394.576769  4.596968         1.286645  6763.478980  ...
# 3  21020.676969  4.496373         1.239825  6079.521052  ...
# 4  19995.849647  4.335537         1.220594  5809.316020  ...
#
#    meat_ratio_cavity_area  meat_ratio_cavity_vol   rho_mvs   rho_vvs  \
# 0                0.034601               0.031335  0.840804  0.592775
# 1                0.033174               0.029986  0.846395  0.587884
# 2                0.040115               0.037996  0.837089  0.598603
# 3                0.031933               0.029688  0.840064  0.602599
# 4                0.032905               0.032489  0.825360  0.586143
#
#     rho_vvm  meat_ratio_feret    nut_vol_sa  meat_ratio_vol_sa  \
# 0  0.705009          1.526275  12880.783084           0.463951
# 1  0.694574          1.425155  13706.563584           0.469242
# 2  0.715100          1.486324  15546.904008           0.465462
# 3  0.717325          1.411052  14347.815998           0.482360
# 4  0.710167          1.314016  12806.076196           0.475517
#
#    vein_ratio_vol_sa  shell_ratio_vol_sa
# 0           0.195673            0.340377
# 1           0.207626            0.323132
# 2           0.203646            0.330892
# 3           0.211936            0.305704
# 4           0.186909            0.337574
#
# [5 rows x 52 columns]

# %%
ucaccsd = sorted(np.unique(UCACCSD))[1:]
print(len(ucaccsd))

ucaccsd = sorted(np.unique(data['UCACCSD']))[1:]
print(len(ucaccsd))
# Out:
# 150
# 149

# %%
quant = np.zeros((len(ucaccsd), data.shape[1]-3 + attr.shape[1] - 5 + 2))
i = 0
for i in range(len(quant)):
    uc = ucaccsd[i]
    
    foo = data[data['UCACCSD'] == uc]
    bar = attr[attr['UCACCSD'] == uc]
    
    quant[i] = np.hstack(([len(foo), len(bar)], 
                          np.nanmean(foo.iloc[:,3:].values, axis = 0),
                          np.nanmean(bar.iloc[:,5:].values, axis = 0)))

# %%
col = ['nut_count', 'plot_count'] + list(data.columns[3:]) + list(attr.columns[5:])

# %%
qual = pd.DataFrame(quant, columns = col)
qual = qual.astype({'nut_count': int, 'plot_count':int})
foo = np.asarray([qual.shape[1]] + list(range(qual.shape[1])))

qual['UCACCSD'] = ucaccsd

qual = qual.iloc[:, foo]
print(qual.shape)

filename = src + 'qual_quant_summary.csv'
print(filename)
qual.to_csv(filename, index=False)

qual.head()
# Out:
# (149, 67)
# ../hpcc/traditional/qual_quant_summary.csv
#        UCACCSD  nut_count  plot_count  nut_length  nut_height  nut_width  \
# 0  03-001-3395          6           4   41.382216   34.552443  34.683614
# 1   04-004-626          9           1   41.655988   36.264753  33.735949
# 2     06-004-4         16           7   37.071349   34.994222  32.470430
# 3    06-005-27         15           4   40.523602   33.250514  31.082693
# 4    06-030-18          5           3   37.920928   32.983651  31.577548
#
#         nut_vol  nut_va3d  nut_ratio_feret     nut_area  ...  ShellThickness  \
# 0  23138.271108  5.061907         1.205837  6740.977257  ...        1.075000
# 1  24456.070925  4.624070         1.234757  6783.986184  ...        1.100000
# 2  20701.067413  4.320171         1.151675  5927.755393  ...        1.114286
# 3  19961.358383  4.605803         1.304487  5915.986251  ...        1.475000
# 4  18617.977820  4.443319         1.201473  5582.720320  ...        1.233333
#
#    PackingTissue  KernelFill  TipShrivel  MinorShrivel  MajorShrivel  \
# 0       5.000000    4.750000    0.000000      0.000000           0.0
# 1       5.000000    6.000000    0.000000      0.000000           0.0
# 2       5.000000    5.000000    0.000000      3.174603           0.0
# 3       5.750000    5.250000    0.000000      0.000000           0.0
# 4       5.666667    5.666667    3.333333      0.000000           0.0
#
#    Plumpness  EaseOfRemoval  PercentKernel     Blank
# 0   4.750000       4.500000      62.329391  0.000000
# 1   4.000000       5.000000      58.398777  0.000000
# 2   3.857143       4.857143      58.931347  5.714286
# 3   3.500000       5.750000      48.263229  2.500000
# 4   5.000000       5.666667      46.102994  0.000000
#
# [5 rows x 67 columns]

# %%
col_labels = ['UCACCSD', 'Batch Name', 'Scan Name',
             'Nut Length','Nut Height', 'Nut Width',
             'Nut Volume',
             'Nut VA3D',
             'Nut Feret Ratio',
             'Nut Surface Area',
             'Nut Sphericity',
             'Nut Convex Surface Area',
             'Nut Convex Volume',
             'Nut Ratio Convex Area',
             'Nut Ratio Convex Volume',
             'Krumbein Index',
             'Sneed Index',
             'Air Volume', 'Kernel Volume', 'Shell Volume', 'Packing Volume',
             'Air Vol Ratio', 'Kernel Vol Ratio', 'Shell Vol Ratio', 'Packing Vol Ratio',
             'Shell Rugosity',
             'Shell Thickness',
             'Protruding Shell Ratio', #
             'Protruding Shell Volume', #
             'Kernel Length', 'Kernel Height', 'Kernel Width',
             'Kernel Surface Area',
             'Kernel Convex Volume',
             'Kernel Convex Area',
             'Kernel Ratio Convex Area',
             'Kernel Ratio Convex Volume',
             'Kernel Cavity Area',
             'Kernel Cavity Volume',
             'Kernel Arc Height',
             'Kernel Cavity Height',
             'Kernel Sphericity',
             'Kernel Ratio Cavity Area',
             'Kernel Ratio Cavity Volume',
             'Density Kernel vs Shell', 'Density Packing vs Shell', 'Density Packing vs Kernel',
             'Kernel Feret Ratio',
             'Nut Vol wo Air', 
             'Kernel Vol Ratio wo Air', 'Packing Vol Ratio wo Air', 'Shell Vol Ratio wo Air',
             'Shell Integrity',
             'Shell Texture',
             'Shell Color',
             'Shell Seal',
             'Shell Strength',
             'Shell Thickness',
             'Packing Tissue',
             'Kernel Fill',
             'Tip Shrivel',
             'Minor Shrivel',
             'Major Shrivel',
             'Plumpness',
             'Ease Of Removal','Kernel Weight Ratio', 'Blank'
             ]

print(len(col_labels))

col_units = ['', '', '',
             ' [mm]',' [mm]', ' [mm]',
             ' [mm$^3$]',
             '',
             '',
             ' [mm$^2$]',
             '',
             ' [mm$^2$]',
             ' [mm$^3$]',
             ' [%]',
             ' [%]',
             '',
             '',
             ' [mm$^3$]', ' [mm$^3$]', ' [mm$^3$]', ' [mm$^3$]',
             ' [%]', ' [%]', ' [%]', ' [%]',
             '',
             ' [mm]',
             ' [%]', #
             ' [mm$^3$]', #
             ' [mm]', ' [mm]', ' [mm]',
             ' [mm$^2$]',
             ' [mm$^3$]',
             ' [mm$^2$]',
             ' [%]',
             ' [%]',
             ' [mm$^2$]',
             ' [mm$^3$]',
             ' [mm]',
             ' [mm]',
             '',
             ' [%]',
             ' [%]',
             ' [%]', ' [%]', ' [%]',
             '',
             ' [mm$^3$]',
             ' [%]', '[%]', ' [%]',
             '',
             '',
             '',
             '',
             '',
             '',
             '',
             '',
             ' [%]',
             ' [%]',
             ' [%]',
             '',
             '',' [%]', ' [%]'
             ]
# Out:
# 67

# %%
foo = pd.DataFrame()
foo['col_labels'] = col_labels
foo['col_units'] = col_units

filename = src + 'col_labels.csv'
foo.to_csv(filename, index=False)

# %%
for i in range(len(col_labels)):
    print(i, i-3, col_labels[i],  qual.columns[i], sep='\t')
# Out:
# 0	-3	UCACCSD	UCACCSD
# 1	-2	Batch Name	nut_count
# 2	-1	Scan Name	plot_count
# 3	0	Nut Length	nut_length
# 4	1	Nut Height	nut_height
# 5	2	Nut Width	nut_width
# 6	3	Nut Volume	nut_vol
# 7	4	Nut VA3D	nut_va3d
# 8	5	Nut Feret Ratio	nut_ratio_feret
# 9	6	Nut Surface Area	nut_area
# 10	7	Nut Sphericity	nut_sphericity
# 11	8	Nut Convex Surface Area	nut_cnvx_area
# 12	9	Nut Convex Volume	nut_cnvx_vol
# 13	10	Nut Ratio Convex Area	nut_ratio_cnvx_area
# 14	11	Nut Ratio Convex Volume	nut_inv_ratio_cnvx_vol
# 15	12	Krumbein Index	krumbein
# 16	13	Sneed Index	sneed
# 17	14	Air Volume	air_vol
# 18	15	Kernel Volume	meat_vol
# 19	16	Shell Volume	shell_vol
# 20	17	Packing Volume	vein_vol
# 21	18	Air Vol Ratio	air_ratio_vol
# 22	19	Kernel Vol Ratio	meat_ratio_vol
# 23	20	Shell Vol Ratio	shell_ratio_vol
# 24	21	Packing Vol Ratio	vein_ratio_vol
# 25	22	Shell Rugosity	shell_rugosity
# 26	23	Shell Thickness	shell_thickness
# 27	24	Protruding Shell Ratio	shell_prot_ratio
# 28	25	Protruding Shell Volume	shell_prot_vol
# 29	26	Kernel Length	meat_length
# 30	27	Kernel Height	meat_height
# 31	28	Kernel Width	meat_width
# 32	29	Kernel Surface Area	meat_area
# 33	30	Kernel Convex Volume	meat_cnvx_vol
# 34	31	Kernel Convex Area	meat_cnvx_area
# 35	32	Kernel Ratio Convex Area	meat_ratio_cnvx_area
# 36	33	Kernel Ratio Convex Volume	meat_inv_ratio_cnvx_vol
# 37	34	Kernel Cavity Area	meat_cavity_area
# 38	35	Kernel Cavity Volume	meat_cavity_vol
# 39	36	Kernel Arc Height	meat_arc_height
# 40	37	Kernel Cavity Height	meat_cavity_height
# 41	38	Kernel Sphericity	meat_sphericity
# 42	39	Kernel Ratio Cavity Area	meat_ratio_cavity_area
# 43	40	Kernel Ratio Cavity Volume	meat_ratio_cavity_vol
# 44	41	Density Kernel vs Shell	rho_mvs
# 45	42	Density Packing vs Shell	rho_vvs
# 46	43	Density Packing vs Kernel	rho_vvm
# 47	44	Kernel Feret Ratio	meat_ratio_feret
# 48	45	Nut Vol wo Air	nut_vol_sa
# 49	46	Kernel Vol Ratio wo Air	meat_ratio_vol_sa
# 50	47	Packing Vol Ratio wo Air	vein_ratio_vol_sa
# 51	48	Shell Vol Ratio wo Air	shell_ratio_vol_sa
# 52	49	Shell Integrity	ShellIntegrity
# 53	50	Shell Texture	ShellTexture
# 54	51	Shell Color	ShellColor
# 55	52	Shell Seal	SEAL
# 56	53	Shell Strength	ShellStrength
# 57	54	Shell Thickness	ShellThickness
# 58	55	Packing Tissue	PackingTissue
# 59	56	Kernel Fill	KernelFill
# 60	57	Tip Shrivel	TipShrivel
# 61	58	Minor Shrivel	MinorShrivel
# 62	59	Major Shrivel	MajorShrivel
# 63	60	Plumpness	Plumpness
# 64	61	Ease Of Removal	EaseOfRemoval
# 65	62	Kernel Weight Ratio	PercentKernel
# 66	63	Blank	Blank
